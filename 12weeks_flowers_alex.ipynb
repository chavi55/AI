# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers import BatchNormalization

# %%
# 꽃 이미지가 저장된 폴더에서 이미지 파일 가져오기 & 라벨링
# X: 꽃 이미지 파일을 numpy 배열로 변환하여 X 배열에 저장
# Z: 꽃 이미지 마다 라벨(꽃 이름)을 영문자열로 Z 배열에 저장

X=[]
Z=[]
IMG_SIZE=224
FLOWER_DAISY_DIR='/content/drive/MyDrive/인공지능/12주차 실습자료/flowers/daisy'
FLOWER_SUNFLOWER_DIR='/content/drive/MyDrive/인공지능/12주차 실습자료/flowers/sunflower'
FLOWER_TULIP_DIR='/content/drive/MyDrive/인공지능/12주차 실습자료/flowers/tulip'
FLOWER_DANDI_DIR='/content/drive/MyDrive/인공지능/12주차 실습자료/flowers/dandelion'
FLOWER_ROSE_DIR='/content/drive/MyDrive/인공지능/12주차 실습자료/flowers/rose'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tqdm import tqdm
import os
import cv2

# 폴더에 저장된 이미지 파일들을 Numpy 데이터로 변환
def make_train_data(flower_type,DIR):
  for img in tqdm(os.listdir(DIR)):
    label = flower_type
    path = os.path.join(DIR, img)
    img2 = cv2.imread(path, cv2.IMREAD_COLOR)
    img2 = cv2.resize(img2, (IMG_SIZE, IMG_SIZE))

    X.append(img2)
    Z.append(label)

# %%
make_train_data('Daisy',FLOWER_DAISY_DIR)
print(len(X))

make_train_data('Sunflower',FLOWER_SUNFLOWER_DIR)
print(len(X))

make_train_data('Tulip',FLOWER_TULIP_DIR)
print(len(X))

make_train_data('Dandelion',FLOWER_DANDI_DIR)
print(len(X))

make_train_data('Rose',FLOWER_ROSE_DIR)
print(len(X))
# Out:
# 100%|██████████| 50/50 [00:07<00:00,  7.09it/s]
# 50
# 100%|██████████| 50/50 [00:06<00:00,  7.33it/s]
# 100
# 100%|██████████| 50/50 [00:07<00:00,  7.06it/s]
# 150
# 100%|██████████| 50/50 [00:08<00:00,  6.04it/s]
# 200
# 100%|██████████| 50/50 [00:07<00:00,  6.59it/s]
# 250

# %%
# Z 배열에 저장된 꽃 이름(문자열)을 원핫인코딩 방식으로 변환하여 Y 배열에 저장
# X 배열에 저장된 꽃 이미지는 모든 값을 255로 나누어줌
# 입력 값을 1보다 작은 값으로 만들기 위함

le = LabelEncoder()
tmp = le.fit_transform(Z)
Y = pd.get_dummies(tmp).values

X = np.array(X)
X = X/255.0

# %%
# 1. 데이터 준비: 훈련 데이터와 시험 데이터로 분할하기
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=1)

x_train.shape, x_test.shape, y_train.shape, y_train.shape
# Out:
# ((200, 224, 224, 3), (50, 224, 224, 3), (200, 5), (200, 5))

# %%
# 2. 모델 구성하기(AlexNet 구성)
img_shape = (IMG_SIZE, IMG_SIZE, 3)

model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=img_shape, kernel_size = (11, 11),
                 strides = 4, padding = 'same', activation='relu'))
# Pooling
model.add(MaxPooling2D(pool_size = (3, 3), strides=2))
# Batch Normalisation before passing it to the next layer
model.add(BatchNormalization())

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(5, 5), strides = 1,
                padding = 'same', activation='relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(3, 3), strides=2))
# Batch Normalisation
model.add(BatchNormalization())

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3, 3), strides = 1,
                padding = 'same', activation='relu'))

# Batch Normalisation
model.add(BatchNormalization())

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3, 3), strides = 1,
                padding = 'same', activation='relu'))

# Batch Normalisation
model.add(BatchNormalization())

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3, 3), strides = 1,
                padding = 'same', activation='relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(3, 3), strides=2))
# Batch Normalisation
model.add(BatchNormalization())

# Passing it to a dense layer
model.add(Flatten())
# 1st Dense Layer
model.add(Dense(2048,activation='relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.5))
# Batch Normalisation
model.add(BatchNormalization())

# 2nd Dense Layer
model.add(Dense(1024, activation='relu'))
# Add Dropout
model.add(Dropout(0.5))
# Batch Normalisation
model.add(BatchNormalization())

# Output Layer
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 56, 56, 96)        34944
#
#  max_pooling2d_4 (MaxPooling  (None, 27, 27, 96)       0
#  2D)
#
#  batch_normalization_7 (Batc  (None, 27, 27, 96)       384
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 27, 27, 256)       614656
#
#  max_pooling2d_5 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  batch_normalization_8 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 13, 13, 384)       885120
#
#  batch_normalization_9 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 13, 13, 384)       1327488
#
#  batch_normalization_10 (Bat  (None, 13, 13, 384)      1536
#  chNormalization)
#
#  conv2d_10 (Conv2D)          (None, 13, 13, 256)       884992
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  batch_normalization_11 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_1 (Dense)             (None, 2048)              18876416
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  batch_normalization_12 (Bat  (None, 2048)             8192
#  chNormalization)
#
#  dense_2 (Dense)             (None, 1024)              2098176
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  batch_normalization_13 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  dense_3 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 24,744,709
# Trainable params: 24,735,813
# Non-trainable params: 8,896
# _________________________________________________________________

# %%
# 3. 모델 학습과정 설정하기
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
# 4. 모델 학습시키기
# 이미지 데이터 증폭을 위한 설정
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images

datagen.fit(x_train)

hist = model.fit(datagen.flow(x_train, y_train), epochs=50, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 7/7 [==============================] - 37s 665ms/step - loss: 2.0425 - accuracy: 0.3700 - val_loss: 59.0092 - val_accuracy: 0.2800
# Epoch 2/50
# 7/7 [==============================] - 3s 356ms/step - loss: 1.8767 - accuracy: 0.3800 - val_loss: 272.2123 - val_accuracy: 0.2800
# Epoch 3/50
# 7/7 [==============================] - 3s 408ms/step - loss: 1.6203 - accuracy: 0.4600 - val_loss: 216.9144 - val_accuracy: 0.2800
# Epoch 4/50
# 7/7 [==============================] - 3s 369ms/step - loss: 1.5063 - accuracy: 0.4600 - val_loss: 86.5907 - val_accuracy: 0.3800
# Epoch 5/50
# 7/7 [==============================] - 3s 410ms/step - loss: 1.3996 - accuracy: 0.5050 - val_loss: 127.8101 - val_accuracy: 0.2800
# Epoch 6/50
# 7/7 [==============================] - 3s 411ms/step - loss: 1.4222 - accuracy: 0.5100 - val_loss: 97.5735 - val_accuracy: 0.3000
# Epoch 7/50
# 7/7 [==============================] - 3s 355ms/step - loss: 1.4531 - accuracy: 0.5100 - val_loss: 76.5751 - val_accuracy: 0.3200
# Epoch 8/50
# 7/7 [==============================] - 3s 357ms/step - loss: 1.2600 - accuracy: 0.5850 - val_loss: 31.7248 - val_accuracy: 0.3400
# Epoch 9/50
# 7/7 [==============================] - 3s 371ms/step - loss: 1.2818 - accuracy: 0.5150 - val_loss: 16.0561 - val_accuracy: 0.2800
# Epoch 10/50
# 7/7 [==============================] - 3s 356ms/step - loss: 1.1185 - accuracy: 0.5900 - val_loss: 12.1906 - val_accuracy: 0.3000
# Epoch 11/50
# 7/7 [==============================] - 3s 351ms/step - loss: 1.2277 - accuracy: 0.5750 - val_loss: 26.3753 - val_accuracy: 0.2600
# Epoch 12/50
# 7/7 [==============================] - 3s 351ms/step - loss: 1.2479 - accuracy: 0.5350 - val_loss: 37.1867 - val_accuracy: 0.1600
# Epoch 13/50
# 7/7 [==============================] - 3s 357ms/step - loss: 1.3359 - accuracy: 0.5200 - val_loss: 36.9224 - val_accuracy: 0.2000
# Epoch 14/50
# 7/7 [==============================] - 3s 355ms/step - loss: 1.2246 - accuracy: 0.4850 - val_loss: 26.7977 - val_accuracy: 0.1800
# Epoch 15/50
# 7/7 [==============================] - 3s 404ms/step - loss: 1.1852 - accuracy: 0.5550 - val_loss: 12.8642 - val_accuracy: 0.2400
# Epoch 16/50
# 7/7 [==============================] - 3s 405ms/step - loss: 1.1455 - accuracy: 0.5850 - val_loss: 9.9541 - val_accuracy: 0.2200
# Epoch 17/50
# 7/7 [==============================] - 3s 383ms/step - loss: 1.2694 - accuracy: 0.5450 - val_loss: 8.4863 - val_accuracy: 0.3800
# Epoch 18/50
# 7/7 [==============================] - 3s 365ms/step - loss: 1.0482 - accuracy: 0.5600 - val_loss: 10.1544 - val_accuracy: 0.3200
# Epoch 19/50
# 7/7 [==============================] - 3s 361ms/step - loss: 1.2560 - accuracy: 0.5650 - val_loss: 5.5774 - val_accuracy: 0.3400
# Epoch 20/50
# 7/7 [==============================] - 3s 353ms/step - loss: 1.2630 - accuracy: 0.6100 - val_loss: 2.9288 - val_accuracy: 0.4200
# Epoch 21/50
# 7/7 [==============================] - 3s 359ms/step - loss: 0.9110 - accuracy: 0.6300 - val_loss: 2.7766 - val_accuracy: 0.5400
# Epoch 22/50
# 7/7 [==============================] - 3s 363ms/step - loss: 1.1863 - accuracy: 0.5750 - val_loss: 2.9929 - val_accuracy: 0.5200
# Epoch 23/50
# 7/7 [==============================] - 3s 420ms/step - loss: 1.0986 - accuracy: 0.5850 - val_loss: 3.3804 - val_accuracy: 0.4000
# Epoch 24/50
# 7/7 [==============================] - 3s 414ms/step - loss: 1.3150 - accuracy: 0.5650 - val_loss: 2.0499 - val_accuracy: 0.4600
# Epoch 25/50
# 7/7 [==============================] - 3s 421ms/step - loss: 1.2007 - accuracy: 0.5650 - val_loss: 2.2177 - val_accuracy: 0.4200
# Epoch 26/50
# 7/7 [==============================] - 3s 416ms/step - loss: 1.1571 - accuracy: 0.5750 - val_loss: 2.5954 - val_accuracy: 0.3800
# Epoch 27/50
# 7/7 [==============================] - 3s 362ms/step - loss: 0.9766 - accuracy: 0.6200 - val_loss: 2.1699 - val_accuracy: 0.5000
# Epoch 28/50
# 7/7 [==============================] - 3s 360ms/step - loss: 0.9699 - accuracy: 0.6100 - val_loss: 2.3635 - val_accuracy: 0.4400
# Epoch 29/50
# 7/7 [==============================] - 3s 359ms/step - loss: 0.9790 - accuracy: 0.6450 - val_loss: 3.0443 - val_accuracy: 0.4200
# Epoch 30/50
# 7/7 [==============================] - 3s 353ms/step - loss: 1.0061 - accuracy: 0.6000 - val_loss: 2.6665 - val_accuracy: 0.3200
# Epoch 31/50
# 7/7 [==============================] - 3s 351ms/step - loss: 1.0050 - accuracy: 0.5950 - val_loss: 3.0410 - val_accuracy: 0.4200
# Epoch 32/50
# 7/7 [==============================] - 3s 355ms/step - loss: 1.0940 - accuracy: 0.6200 - val_loss: 3.4714 - val_accuracy: 0.3400
# Epoch 33/50
# 7/7 [==============================] - 3s 358ms/step - loss: 1.2221 - accuracy: 0.5400 - val_loss: 3.7204 - val_accuracy: 0.3600
# Epoch 34/50
# 7/7 [==============================] - 3s 405ms/step - loss: 1.0320 - accuracy: 0.5900 - val_loss: 3.7233 - val_accuracy: 0.3400
# Epoch 35/50
# 7/7 [==============================] - 3s 360ms/step - loss: 1.0413 - accuracy: 0.6250 - val_loss: 2.6536 - val_accuracy: 0.4000
# Epoch 36/50
# 7/7 [==============================] - 3s 365ms/step - loss: 0.9763 - accuracy: 0.6400 - val_loss: 2.4027 - val_accuracy: 0.5400
# Epoch 37/50
# 7/7 [==============================] - 3s 358ms/step - loss: 0.9384 - accuracy: 0.5850 - val_loss: 2.7667 - val_accuracy: 0.4400
# Epoch 38/50
# 7/7 [==============================] - 3s 358ms/step - loss: 1.0798 - accuracy: 0.6150 - val_loss: 2.9473 - val_accuracy: 0.4000
# Epoch 39/50
# 7/7 [==============================] - 3s 356ms/step - loss: 0.9167 - accuracy: 0.6600 - val_loss: 3.7522 - val_accuracy: 0.4200
# Epoch 40/50
# 7/7 [==============================] - 3s 364ms/step - loss: 0.7925 - accuracy: 0.7050 - val_loss: 3.3306 - val_accuracy: 0.2800
# Epoch 41/50
# 7/7 [==============================] - 3s 353ms/step - loss: 0.9565 - accuracy: 0.6500 - val_loss: 4.3350 - val_accuracy: 0.3200
# Epoch 42/50
# 7/7 [==============================] - 3s 348ms/step - loss: 0.9765 - accuracy: 0.6350 - val_loss: 4.3992 - val_accuracy: 0.3400
# Epoch 43/50
# 7/7 [==============================] - 3s 356ms/step - loss: 0.8988 - accuracy: 0.6550 - val_loss: 2.1435 - val_accuracy: 0.4400
# Epoch 44/50
# 7/7 [==============================] - 3s 351ms/step - loss: 1.0661 - accuracy: 0.6000 - val_loss: 3.8788 - val_accuracy: 0.3400
# Epoch 45/50
# 7/7 [==============================] - 3s 353ms/step - loss: 0.9828 - accuracy: 0.5800 - val_loss: 2.5762 - val_accuracy: 0.4200
# Epoch 46/50
# 7/7 [==============================] - 3s 354ms/step - loss: 0.9810 - accuracy: 0.6300 - val_loss: 2.6167 - val_accuracy: 0.4000
# Epoch 47/50
# 7/7 [==============================] - 3s 353ms/step - loss: 1.0950 - accuracy: 0.5950 - val_loss: 12.1127 - val_accuracy: 0.2600
# Epoch 48/50
# 7/7 [==============================] - 3s 359ms/step - loss: 1.1265 - accuracy: 0.6050 - val_loss: 3.6684 - val_accuracy: 0.4600
# Epoch 49/50
# 7/7 [==============================] - 3s 408ms/step - loss: 1.0889 - accuracy: 0.5750 - val_loss: 3.4758 - val_accuracy: 0.5000
# Epoch 50/50
# 7/7 [==============================] - 3s 362ms/step - loss: 0.7735 - accuracy: 0.6900 - val_loss: 3.4519 - val_accuracy: 0.4600

# %%
# 5. 학습과정 살펴보기
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])

plt.subplot(1, 2, 2)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
# 6. 학습된 모델로 예측하기
pred = model.predict(x_test)
pred_num = np.argmax(pred, axis=1)
pred_num
# Out:
# array([0, 4, 2, 1, 2, 1, 0, 4, 1, 1, 0, 0, 4, 0, 4, 0, 1, 3, 0, 3, 4, 0,
#        0, 0, 4, 2, 4, 1, 1, 4, 0, 1, 3, 4, 3, 2, 4, 0, 0, 4, 4, 0, 3, 4,
#        0, 4, 0, 0, 4, 0])

# %%
# 예측결과 올바른 결과 8개(prop_class)와 틀린 결과 8개(mis_class) 선택
i=0
prop_class=[]
mis_class=[]

for i in range(len(y_test)):
  if(np.argmax(y_test[i] == pred_num[i])): #정답 == 예측값
    prop_class.append(i)
  if(len(prop_class) == 8):
    break

i = 0

for i in range(len(y_test)):
  if(not np.argmax(y_test[i] == pred_num[i])): #정답 == 예측값
    mis_class.append(i)
  if(len(mis_class) == 8):
    break

# %%
# 올바른 예측 결과 보여주기

count = 0
fig, ax = plt.subplots(4, 2)
fig.set_size_inches(15, 15)
for i in range(4):
  for j in range(2):
    #ax[i, j].imshow(x_test[mis_class[count]])
    ax[i, j].imshow(x_test[prop_class[count]])
    ax[i, j].set_title("Predicted : "+str(pred_num[prop_class[count]]) + 
                       "Label : " + str(np.argmax([y_test[prop_class[count]]])))
    count += 1

plt.show()

# %%
# 잘못된 결과 보여주기

count = 0
fig, ax = plt.subplots(4, 2)
fig.set_size_inches(15, 15)
for i in range(4):
  for j in range(2):
    ax[i, j].imshow(x_test[mis_class[count]])
    ax[i, j].set_title("Predicted : "+str(pred_num[mis_class[count]]) + 
                       "Label : " + str(np.argmax([y_test[mis_class[count]]])))
    count += 1

plt.show()
