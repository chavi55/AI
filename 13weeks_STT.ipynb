# %% [markdown]
# 참고자료: https://fortes-arthur.medium.com/hands-on-speech-recognition-engine-with-keras-and-python-c60488ac53cd

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import os
import librosa
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# 훈련 데이터 위치
train_audio_path = '/content/drive/MyDrive/인공지능/13weeks_STT/sound/audio/'

# 음성 파일 1개 시각화해보기
yes = 'yes/00f0204f_nohash_0.wav'
samples, sample_rate = librosa.load(train_audio_path + yes, sr = 16000)
fig = plt.figure(figsize=(14, 8))
ax = fig.add_subplot(2, 1, 1)
ax.set_title('Raw wave of ' + yes)
ax.set_xlabel('Time')
ax.set_ylabel('Amplitude')
ax.plot(np.linspace(0, sample_rate/len(samples), sample_rate), samples)

# %%
ipd.Audio(samples, rate=sample_rate) #야쒸
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(sample_rate)
# Out:
# 16000

# %%
# Resampling: 주파수 변경
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples, rate=8000) #야!
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **List Comprehension**
#
# * list와 for문만을 이용한 예시
# > 1. for문 하나만 있을 때의 작성 형식 :
# >> * [식  for 변수  in 리스트]
# >> * list(식 for 변수 in 리스트)
# > 2. for문 여러개 있을 때의 작성 형식 :
# >> * [식 for 변수1 in 리스트1 for 변수2 in 리스트2]
# >> * list(식 for 변수1 in 리스트1 for 변수2 in 리스트2)
# > 3. list와 for문, if 조건문을 이용한 예시
# > * for문과 if 조건문이 한개일 때 작성 형식 :
# >> * [식 for 변수 in 리스트 if 조건식]
# > * for문과 if 조건문이 여러개일 때 작성 형식 :
# >> * [식 for 변수1 in 리스트1 if 조건식1 ... for 변수N in 리스트N if 조건식N]
# > 4. list와 for문, if .. else .. 조건문을 이용한 예시
# > * for문, if .. else .. 조건문 작성 형식 :
# >> * [식1 if 조건식 else 식2 for 변수 in 리스트 ]

# %%
# 오디오 데이터 가져오기
labels = os.listdir(train_audio_path)
no_of_waves = []
waves = []
for label in labels:
  waves = [f for f in os.listdir(train_audio_path + label) if f.endswith('.wav')]
  no_of_waves.append(len(waves))

plt.figure(figsize=(14, 5))
index = np.arange(len(labels))
plt.bar(index, no_of_waves)
plt.xlabel('Commands', fontsize=12)
plt.ylabel('No. of wav files', fontsize=12)
plt.xticks(index, labels, fontsize=15, rotation=60)
plt.title('No. of wav files for each command')
plt.show()

# %%
labels
# Out:
# ['yes', 'go', 'on', 'up', 'stop', 'off', 'down', 'right', 'no', 'left']

# %%
# 오디오 파일 전처리
# 1. Resampling: 주파수 변환
# 2. 1초보다 짧은 음성 파일 삭제
from tqdm import tqdm

all_wave = []
all_label = []

for label in labels:
  waves = [f for f in os.listdir(train_audio_path + label) if f.endswith('.wav')]
  for wav in tqdm(waves):
    samples, sample_rate = librosa.load(train_audio_path + label + '/' + wav, sr=16000)
    samples = librosa.resample(samples, sample_rate, 8000)
    if(len(samples) == 8000):
      all_wave.append(samples)
      all_label.append(label)
# Out:
# 100%|██████████| 100/100 [00:22<00:00,  4.51it/s]
# 100%|██████████| 100/100 [00:16<00:00,  5.89it/s]
# 100%|██████████| 100/100 [00:18<00:00,  5.36it/s]
# 100%|██████████| 100/100 [00:19<00:00,  5.06it/s]
# 100%|██████████| 111/111 [00:18<00:00,  6.01it/s]
# 100%|██████████| 100/100 [00:17<00:00,  5.64it/s]
# 100%|██████████| 100/100 [00:16<00:00,  5.97it/s]
# 100%|██████████| 100/100 [00:17<00:00,  5.73it/s]
# 100%|██████████| 100/100 [00:16<00:00,  5.90it/s]
# 100%|██████████| 100/100 [00:17<00:00,  5.69it/s]

# %%
print(len(all_label), len(all_wave))
# Out:
# 910 910

# %%
# label 문자열을 one-hot encoding으로 변환하여 y값 생성하기

from sklearn.preprocessing import LabelEncoder
import pandas as pd

le = LabelEncoder()
tmp = le.fit_transform(all_label)
y = pd.get_dummies(tmp).values

y.shape
# Out:
# (910, 10)

# %%
# 오디오 데이터를 2차원 배열에서 3차원 배열로 변환
all_wave=np.array(all_wave).reshape(-1, 8000, 1)
all_wave.shape
# Out:
# (910, 8000, 1)

# %%
# 훈련 데이터와 시험 데이터로 나누기
from sklearn.model_selection import train_test_split

# stratify: 지정한 Data의 비율을 유지한다. 
#           예를 들어, Label Set인 Y가 25%의 0과 75%의 1로 이루어진 Binary Set일 때, 
#           stratify=Y로 설정하면 나누어진 데이터셋들도 0과 1을 각각 25%, 75%로 유지한 채 분할된다.

x_train, x_val, y_train, y_val = train_test_split(all_wave, y, test_size = 0.2, random_state=7, shuffle=True)

x_train.shape, x_val.shape, y_train.shape, y_val.shape
# Out:
# ((728, 8000, 1), (182, 8000, 1), (728, 10), (182, 10))

# %%
# 모델 구성하기
from keras.layers import Bidirectional, BatchNormalization, CuDNNGRU, TimeDistributed
from keras.layers import Dense, Dropout, Flatten, Conv1D, Input, MaxPooling1D
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

# %% [markdown]
# **Functional API로 만든 모델**
#
# Functional API는 각 층을 일종의 함수(function)로서 정의합니다. 그리고 각 함수를 조합하기 위한 연산자들을 제공하는데, 이를 이용하여 신경망을 설계합니다. Functional API로 FFNN, RNN 등 다양한 모델을 만들면서 기존의 sequential API와의 차이를 이해해봅시다.
#
# Functional API는 입력의 크기(shape)를 명시한 입력층(Input layer)을 모델의 앞단에 정의해주어야 합니다.
#
# * Input() 함수에 입력의 크기를 정의합니다.
# * 이전층을 다음층 함수의 입력으로 사용하고, 변수에 할당합니다.
# * Model() 함수에 입력과 출력을 정의합니다.

# %% [markdown]
# **모델 설계**
#
# * Conv1d 및 GRU 계층을 사용하여 음성 인식에 사용되는 네트워크를 모델링
# * Conv1d는 한 차원만을 따라 컨볼루션을 수행하는 컨볼루션 신경망
# * GRU(Gated Recurrent Unit)는 표준 순환 신경망과 함께 제공되는 기울기 소실 문제를 해결하는 것을 목표함. GRU도 LSTM의 변형으로 볼 수 있음

# %%
K.clear_session()

inputs = Input(shape=(8000, 1))
x = BatchNormalization(axis=-1, momentum=0.99, epsilon=1e-3, center=True, scale=True)(inputs)

#First Conv1D layer
x = Conv1D(8, 13, padding='valid', activation='relu', strides=1)(x)
x = MaxPooling1D(3)(x)
x = Dropout(0.3)(x)

#Second Conv1D layer
x = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(x)
x = MaxPooling1D(3)(x)
x = Dropout(0.3)(x)

#Third Conv1D layer
x = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(x)
x = MaxPooling1D(3)(x)
x = Dropout(0.3)(x)

#GRU(Gated Recurrent Unit) layer
x = BatchNormalization(axis=-1, momentum=0.99, epsilon=1e-3, center=True, scale=True)(x)

x = Bidirectional(CuDNNGRU(128, return_sequences=True), merge_mode='sum')(x)
x = Bidirectional(CuDNNGRU(128, return_sequences=True), merge_mode='sum')(x)
x = Bidirectional(CuDNNGRU(128, return_sequences=False), merge_mode='sum')(x)

x = BatchNormalization(axis=-1, momentum=0.99, epsilon=1e-3, center=True, scale=True)(x)

#Dense Layer 1
x = Dense(256, activation='relu')(x)
outputs = Dense(len(labels), activation='softmax')(x)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 8000, 1)]         0
#
#  batch_normalization (BatchN  (None, 8000, 1)          4
#  ormalization)
#
#  conv1d (Conv1D)             (None, 7988, 8)           112
#
#  max_pooling1d (MaxPooling1D  (None, 2662, 8)          0
#  )
#
#  dropout (Dropout)           (None, 2662, 8)           0
#
#  conv1d_1 (Conv1D)           (None, 2652, 16)          1424
#
#  max_pooling1d_1 (MaxPooling  (None, 884, 16)          0
#  1D)
#
#  dropout_1 (Dropout)         (None, 884, 16)           0
#
#  conv1d_2 (Conv1D)           (None, 876, 32)           4640
#
#  max_pooling1d_2 (MaxPooling  (None, 292, 32)          0
#  1D)
#
#  dropout_2 (Dropout)         (None, 292, 32)           0
#
#  batch_normalization_1 (Batc  (None, 292, 32)          128
#  hNormalization)
#
#  bidirectional (Bidirectiona  (None, 292, 128)         124416
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 292, 128)         198144
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 128)              198144
#  nal)
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense (Dense)               (None, 256)               33024
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 563,118
# Trainable params: 562,796
# Non-trainable params: 322
# _________________________________________________________________

# %%
# 학습하기

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10,
                           min_delta = 0.001)
hist = model.fit(x_train, y_train, epochs=100, callbacks=[early_stop], 
                 batch_size=32, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 23/23 [==============================] - 27s 557ms/step - loss: 2.4729 - accuracy: 0.1044 - val_loss: 2.3040 - val_accuracy: 0.0879
# Epoch 2/100
# 23/23 [==============================] - 10s 449ms/step - loss: 2.3584 - accuracy: 0.1058 - val_loss: 2.3189 - val_accuracy: 0.0934
# Epoch 3/100
# 23/23 [==============================] - 10s 450ms/step - loss: 2.3477 - accuracy: 0.1236 - val_loss: 2.3521 - val_accuracy: 0.0440
# Epoch 4/100
# 23/23 [==============================] - 10s 446ms/step - loss: 2.3422 - accuracy: 0.1195 - val_loss: 2.3531 - val_accuracy: 0.0769
# Epoch 5/100
# 23/23 [==============================] - 10s 442ms/step - loss: 2.2369 - accuracy: 0.1799 - val_loss: 2.4393 - val_accuracy: 0.0934
# Epoch 6/100
# 23/23 [==============================] - 10s 443ms/step - loss: 1.8849 - accuracy: 0.2857 - val_loss: 2.8707 - val_accuracy: 0.1209
# Epoch 7/100
# 23/23 [==============================] - 10s 444ms/step - loss: 1.6550 - accuracy: 0.3599 - val_loss: 2.6633 - val_accuracy: 0.0989
# Epoch 8/100
# 23/23 [==============================] - 10s 444ms/step - loss: 1.5216 - accuracy: 0.4066 - val_loss: 2.5633 - val_accuracy: 0.1429
# Epoch 9/100
# 23/23 [==============================] - 10s 445ms/step - loss: 1.4150 - accuracy: 0.4560 - val_loss: 2.3547 - val_accuracy: 0.1593
# Epoch 10/100
# 23/23 [==============================] - 10s 444ms/step - loss: 1.3417 - accuracy: 0.5096 - val_loss: 1.8676 - val_accuracy: 0.2582
# Epoch 11/100
# 23/23 [==============================] - 10s 443ms/step - loss: 1.2337 - accuracy: 0.5426 - val_loss: 1.9467 - val_accuracy: 0.2473
# Epoch 12/100
# 23/23 [==============================] - 10s 444ms/step - loss: 1.1718 - accuracy: 0.5893 - val_loss: 2.1289 - val_accuracy: 0.2418
# Epoch 13/100
# 23/23 [==============================] - 10s 443ms/step - loss: 1.0105 - accuracy: 0.6099 - val_loss: 1.7438 - val_accuracy: 0.3187
# Epoch 14/100
# 23/23 [==============================] - 10s 437ms/step - loss: 1.0123 - accuracy: 0.6236 - val_loss: 1.7406 - val_accuracy: 0.4011
# Epoch 15/100
# 23/23 [==============================] - 10s 426ms/step - loss: 0.9148 - accuracy: 0.6580 - val_loss: 2.5890 - val_accuracy: 0.2143
# Epoch 16/100
# 23/23 [==============================] - 10s 424ms/step - loss: 0.9064 - accuracy: 0.6621 - val_loss: 2.1757 - val_accuracy: 0.3022
# Epoch 17/100
# 23/23 [==============================] - 10s 424ms/step - loss: 0.8092 - accuracy: 0.6951 - val_loss: 2.0435 - val_accuracy: 0.3516
# Epoch 18/100
# 23/23 [==============================] - 10s 424ms/step - loss: 0.6972 - accuracy: 0.7459 - val_loss: 1.4339 - val_accuracy: 0.4835
# Epoch 19/100
# 23/23 [==============================] - 10s 424ms/step - loss: 0.6002 - accuracy: 0.7843 - val_loss: 1.8079 - val_accuracy: 0.4560
# Epoch 20/100
# 23/23 [==============================] - 10s 424ms/step - loss: 0.6251 - accuracy: 0.7706 - val_loss: 1.6497 - val_accuracy: 0.5110
# Epoch 21/100
# 23/23 [==============================] - 10s 425ms/step - loss: 0.5277 - accuracy: 0.8104 - val_loss: 1.8506 - val_accuracy: 0.4451
# Epoch 22/100
# 23/23 [==============================] - 10s 425ms/step - loss: 0.5107 - accuracy: 0.8132 - val_loss: 1.5298 - val_accuracy: 0.5000
# Epoch 23/100
# 23/23 [==============================] - 10s 425ms/step - loss: 0.4874 - accuracy: 0.8063 - val_loss: 1.2664 - val_accuracy: 0.5879
# Epoch 24/100
# 23/23 [==============================] - 10s 425ms/step - loss: 0.4585 - accuracy: 0.8269 - val_loss: 1.6836 - val_accuracy: 0.5330
# Epoch 25/100
# 23/23 [==============================] - 10s 423ms/step - loss: 0.4536 - accuracy: 0.8434 - val_loss: 1.2186 - val_accuracy: 0.6099
# Epoch 26/100
# 23/23 [==============================] - 9s 415ms/step - loss: 0.3755 - accuracy: 0.8654 - val_loss: 1.0881 - val_accuracy: 0.6538
# Epoch 27/100
# 23/23 [==============================] - 9s 412ms/step - loss: 0.3587 - accuracy: 0.8874 - val_loss: 0.9084 - val_accuracy: 0.7143
# Epoch 28/100
# 23/23 [==============================] - 9s 412ms/step - loss: 0.3005 - accuracy: 0.9093 - val_loss: 0.9896 - val_accuracy: 0.6978
# Epoch 29/100
# 23/23 [==============================] - 9s 407ms/step - loss: 0.2929 - accuracy: 0.8970 - val_loss: 1.3080 - val_accuracy: 0.6264
# Epoch 30/100
# 23/23 [==============================] - 9s 401ms/step - loss: 0.3816 - accuracy: 0.8585 - val_loss: 1.4359 - val_accuracy: 0.5989
# Epoch 31/100
# 23/23 [==============================] - 9s 400ms/step - loss: 0.2851 - accuracy: 0.9011 - val_loss: 1.4833 - val_accuracy: 0.5934
# Epoch 32/100
# 23/23 [==============================] - 9s 401ms/step - loss: 0.2607 - accuracy: 0.8984 - val_loss: 0.7912 - val_accuracy: 0.7692
# Epoch 33/100
# 23/23 [==============================] - 9s 400ms/step - loss: 0.2500 - accuracy: 0.9121 - val_loss: 1.3967 - val_accuracy: 0.5659
# Epoch 34/100
# 23/23 [==============================] - 9s 401ms/step - loss: 0.2283 - accuracy: 0.9203 - val_loss: 0.8284 - val_accuracy: 0.7527
# Epoch 35/100
# 23/23 [==============================] - 9s 401ms/step - loss: 0.2258 - accuracy: 0.9217 - val_loss: 1.0286 - val_accuracy: 0.6758
# Epoch 36/100
# 23/23 [==============================] - 9s 401ms/step - loss: 0.2117 - accuracy: 0.9272 - val_loss: 0.9928 - val_accuracy: 0.6593
# Epoch 37/100
# 23/23 [==============================] - 9s 402ms/step - loss: 0.2438 - accuracy: 0.9107 - val_loss: 0.9850 - val_accuracy: 0.7418
# Epoch 38/100
# 23/23 [==============================] - 9s 402ms/step - loss: 0.3165 - accuracy: 0.8887 - val_loss: 2.2109 - val_accuracy: 0.4780
# Epoch 39/100
# 23/23 [==============================] - 9s 402ms/step - loss: 0.2100 - accuracy: 0.9354 - val_loss: 0.9305 - val_accuracy: 0.7527
# Epoch 40/100
# 23/23 [==============================] - 9s 400ms/step - loss: 0.2122 - accuracy: 0.9272 - val_loss: 0.8411 - val_accuracy: 0.7473
# Epoch 41/100
# 23/23 [==============================] - 9s 400ms/step - loss: 0.1852 - accuracy: 0.9341 - val_loss: 1.1244 - val_accuracy: 0.6758
# Epoch 42/100
# 23/23 [==============================] - 9s 401ms/step - loss: 0.1714 - accuracy: 0.9368 - val_loss: 1.2010 - val_accuracy: 0.6538
# Epoch 00042: early stopping

# %%
# 훈련 결과 그래프로 확인하기

plt.plot(hist.history['loss'], label='train')
plt.plot(hist.history['val_loss'], label='val')
plt.legend()
plt.show()

# %%
plt.plot(hist.history['accuracy'], label='train')
plt.plot(hist.history['val_accuracy'], label='val')
plt.legend()
plt.show()

# %%
# 결과를 문자로 보여주기 위한 함수 정의
classes = list(le.classes_)
print(classes)

def predict(audio):
  prob = model.predict(audio.reshape(1, 8000, 1))
  index = np.argmax(prob[0])
  return classes[index]
# Out:
# ['down', 'go', 'left', 'no', 'off', 'on', 'right', 'stop', 'up', 'yes']

# %%
# 새로운 데이터로 확인하기

test_audio_path = '/content/drive/MyDrive/인공지능/13weeks_STT/sound/test/'

for f in os.listdir(test_audio_path):
  samples, sample_rate = librosa.load(test_audio_path + f, sr = 16000)
  samples = librosa.resample(samples, sample_rate, 8000)
  print('음성파일: {}에 대해서 {}라고 예측하였습니다.'.format(f, predict(samples)))
# Out:
# 음성파일: yes.wav에 대해서 yes라고 예측하였습니다.
# 음성파일: stop.wav에 대해서 stop라고 예측하였습니다.
# 음성파일: right.wav에 대해서 right라고 예측하였습니다.
# 음성파일: left.wav에 대해서 yes라고 예측하였습니다.
# 음성파일: up.wav에 대해서 up라고 예측하였습니다.
# 음성파일: go.wav에 대해서 no라고 예측하였습니다.
# 음성파일: on.wav에 대해서 on라고 예측하였습니다.
# 음성파일: down.wav에 대해서 down라고 예측하였습니다.
# 음성파일: off.wav에 대해서 on라고 예측하였습니다.
